# %%
import random
import string

# %% [markdown]
# ## generate population
#
# 첫 세대 생성

# %%
# 비밀번호와 최대 최소 갯수
password = 'brad1234'
min_len = 2
max_len = 10

# 임의의 문자를 만듬
def generate_word(length):
    result = ''
    x = ''.join(random.sample(string.ascii_letters + string.digits, k=length))
    return x

# 옛날 옛적 빵형이 지구에 빛이 있으라하여 첫번째 세대가 태어났다
def generate_population(size, min_len, max_len):
    population = []
    for i in range(size):
        # generate words with balanced length
        length = i % (max_len - min_len + 1) + min_len
        population.append(generate_word(length))
    return population

# %%
print(generate_word(length=10))
pop = generate_population(size=100, min_len=min_len, max_len=max_len)
pop
# Out:
# QADEnvqdKU
# ['40',
#  'bWa',
#  'YZ13',
#  'YoAi2',
#  '8TocZj',
#  'VMknA25',
#  '16mknWqD',
#  'cDn0xsBUJ',
#  '7xUMvsnCyV',
#  'cX',
#  '0TZ',
#  'XMoR',
#  'RSG5A',
#  'cQkmX7',
#  'nP9FmOR',
#  'WNgLEFtv',
#  'NGmPd2JAh',
#  'exRZUz1F6Y',
#  'x4',
#  '5XP',
#  'S286',
#  'TwLum',
#  'o4xGWA',
#  'iIDV7wP',
#  'qkKJpHRL',
#  'CIGDy2wXt',
#  'GRfICKrDc6',
#  'xD',
#  'IMd',
#  'pzSG',
#  'U29e4',
#  'I0Texn',
#  'ZhcmF8J',
#  'dm2Czqhu',
#  'pZY1N6H4a',
#  'JftTDZK6nz',
#  'fV',
#  '0vG',
#  '2BMu',
#  '8aeHT',
#  'MCngBD',
#  'Q8z2hJD',
#  'ZvETHn0r',
#  'SIBNjvi90',
#  'zHC9BLdhtu',
#  '5D',
#  'JYC',
#  'T4wR',
#  'RVQJY',
#  'fFLRMU',
#  '0WL9Ahq',
#  'TYodtCIi',
#  'OrDVtCsNz',
#  '2QOFoRP9cK',
#  'ky',
#  'Av5',
#  'W4XO',
#  '2PboE',
#  'XBmzuf',
#  'T2M4XfU',
#  'zh5riBCJ',
#  '7IHBZStpK',
#  'gA4dfwsLEU',
#  'Uo',
#  'Kmn',
#  'm3OE',
#  'QxH8O',
#  'hqX65G',
#  '8OhTrpV',
#  'dS2LyjQC',
#  'IOYRzr64N',
#  'FitJe14g38',
#  '7R',
#  '1Qr',
#  'WsRI',
#  'yTuxC',
#  'CIOZpf',
#  'toqFPO4',
#  'qzOAvVie',
#  '3SnaZGiU8',
#  'ixLdb6y7TY',
#  'qa',
#  'UG0',
#  'jR39',
#  'dXpUy',
#  'XShmIE',
#  'MGNDbiO',
#  'DpPmzb07',
#  'MTGjrReY1',
#  'YvaPCcTW8f',
#  'rv',
#  'h5C',
#  'zW2h',
#  'yj1P9',
#  '09Aho3',
#  'bLwXvYH',
#  'PjHk9hmS',
#  'kUM4beuNH',
#  'Ghn9S7Lbd2',
#  'ci']

# %% [markdown]
# ## Fitness Function
#
# 유전자 점수 확인

# %%
def fitness(password, test_word):
    score = 0

    if len(password) != len(test_word):
        return score
    
    # if fit length, I'll give you score 0.5
    len_score = 0.5
    score += len_score

    for i in range(len(password)):
        if password[i] == test_word[i]:
            score += 1

    # 백점 만점에 몇점?
    return score / (len(password) + len_score) * 100

# %%
fitness('abcde', 'abcdE')
# Out:
# 81.81818181818183

# %% [markdown]
# ## Compute Performance and Select Survivors
#
# 정답에 가까운 값 선택

# %%
def compute_performace(population, password):
    performance_list = []
    for individual in population:
        score = fitness(password, individual)

        # we can predict length of password
        if score > 0:
            pred_len = len(individual)
        performance_list.append([individual, score])

    # 점수의 내림차순으로 정렬
    population_sorted = sorted(performance_list, key=lambda x: x[1], reverse=True)
    return population_sorted, pred_len

def select_survivors(population_sorted, best_sample, lucky_few, password_len):
    next_generation = []

    for i in range(best_sample):
        if population_sorted[i][1] > 0:
            next_generation.append(population_sorted[i][0])

    lucky_survivors = random.sample(population_sorted, k=lucky_few)
    for l in lucky_survivors:
        next_generation.append(l[0])
    
    # generate new population if next_generation is too small
    while len(next_generation) < best_sample + lucky_few:
        next_generation.append(generate_word(length=password_len))

    random.shuffle(next_generation)
    return next_generation

pop_sorted, pred_len = compute_performace(pop, password)
survivors = select_survivors(pop_sorted, best_sample=20, lucky_few=20, password_len=pred_len)

print('Password length must be %s' % pred_len)
survivors
# Out:
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 1.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# Password length must be 8
# ['I0Texn',
#  'CIOZpf',
#  '2BMu',
#  'MTGjrReY1',
#  'jR39',
#  'zh5riBCJ',
#  'qkKJpHRL',
#  '832fYTvy',
#  'qzOAvVie',
#  'wlBPe6R2',
#  'V4T1glqQ',
#  '7IHBZStpK',
#  'z4ZsR30N',
#  'YvaPCcTW8f',
#  '0UQpnYHM',
#  'WNgLEFtv',
#  'DpPmzb07',
#  'iFybUeCO',
#  '8TocZj',
#  'qkKJpHRL',
#  '0ic7FwCl',
#  'PjHk9hmS',
#  '16mknWqD',
#  'YoAi2',
#  'hBPHSRld',
#  'JftTDZK6nz',
#  'm3OE',
#  'h5C',
#  'dS2LyjQC',
#  'Q8z2hJD',
#  'ZvETHn0r',
#  'dm2Czqhu',
#  '09Aho3',
#  'dS2LyjQC',
#  'qzOAvVie',
#  'dm2Czqhu',
#  'JItBe0SL',
#  'cQkmX7',
#  'qa',
#  'TYodtCIi']

# %% [markdown]
# # Create Children

# %% [markdown]
# 상위 스코어 20개와 무작위로 뽑은 20개를 가지고 교배한다.

# %%
def create_child(individual1, individual2):
    child = ''
    min_len_ind = min(len(individual1), len(individual2))
    for i in range(min_len_ind):
        if (int(100 * random.random()) < 50):
            child += individual1[i]
        else:
            child += individual2[i]
    return child

# 우리는 그렇게 자비롭지 않기때문에 부모를 내 맘대로 짝지어줄 것이다
def create_children(parents, n_child):
    next_population = []
    for i in range(int(len(parents)/2)):
        for j in range(n_child):
            next_population.append(create_child(parents[i], parents[len(parents) - 1 - i]))
    return next_population

children = create_children(survivors, 5)

children
# Out:
# ['T0Tdxn',
#  'T0Texn',
#  'I0oetn',
#  'TYodtC',
#  'TYTexC',
#  'CI',
#  'CI',
#  'CI',
#  'CI',
#  'Ca',
#  'cQMm',
#  '2Qkm',
#  '2BMm',
#  'cBMu',
#  '2BMm',
#  'JItBr0eL',
#  'MTtBeRSY',
#  'JIGjr0eL',
#  'JTtje0eY',
#  'MItBeReL',
#  'dm29',
#  'dR29',
#  'dm3C',
#  'jR39',
#  'dm29',
#  'qh5AiVCJ',
#  'zzOrvBiJ',
#  'zh5riBCe',
#  'qhOriVie',
#  'qh5rvVie',
#  'dS2LpHRL',
#  'qk2LpHQC',
#  'dkKLyHQC',
#  'dk2LpjQC',
#  'qSKLpHRC',
#  '03Aho3',
#  '092foT',
#  '83Aho3',
#  '89AhY3',
#  '89Afo3',
#  'qmOAzVie',
#  'dmOCzqhe',
#  'qm2AzViu',
#  'qzOAzVie',
#  'dm2Cvqhe',
#  'ZvBTHnRr',
#  'wvETe60r',
#  'ZlBTenR2',
#  'wlEPe602',
#  'ZlETHnR2',
#  'Q4z2glq',
#  'V4T2hlq',
#  'Q4T1gJq',
#  'Q4T1gJD',
#  'Q8z1gJD',
#  '7SHLyStp',
#  '7I2ByStC',
#  'dIHLyjQC',
#  'dS2BZjtp',
#  '7SHLySQC',
#  'z5C',
#  'h5C',
#  'z4C',
#  'h5Z',
#  'h5C',
#  'mvaP',
#  'Y3aE',
#  'Y3OE',
#  'YvOP',
#  'YvaE',
#  '0UQTnZH6',
#  '0UQpDZK6',
#  '0UtTDZK6',
#  '0ftpnYH6',
#  '0fQpDZKM',
#  'hBPHERld',
#  'hNgHSRlv',
#  'WBgHSFld',
#  'WNgLSFtd',
#  'hNPLSFtd',
#  'DoPi2',
#  'DoAi2',
#  'YoAm2',
#  'DpPm2',
#  'DoAi2',
#  '16mbneCD',
#  '16mkUWCD',
#  '16yknWqO',
#  '16mkneqD',
#  'i6ykUeCD',
#  'PTHc9j',
#  '8jHkZh',
#  '8jok9h',
#  'PTok9h',
#  'PTHc9h',
#  'qicJpwCl',
#  'qkc7FwCL',
#  'qicJFwCL',
#  '0ic7pwRl',
#  'qic7pwCl']

# %% [markdown]
# # Mutation
#
# 랜덤 인덱스를 뽑아서 값을 랜덤으로 바꿈

# %%
def mutate_word(word):
    idx = int(random.random() * len(word))
    if (idx == 0):
        word = random.choice(string.ascii_letters + string.digits) + word[1:]
    else:
        word = word[:idx] + random.choice(string.ascii_letters + string.digits) + word[idx+1:]
    return word

def mutate_population(population, chance_of_mutation):
    for i in range(len(population)):
        if random.random() * 100 < chance_of_mutation:
            population[i] = mutate_word(population[i])
    return population

new_generation = mutate_population(population=children, chance_of_mutation=10)

new_generation
# Out:
# ['T0Tdxn',
#  'T0Texn',
#  'I0oetn',
#  'TYodtC',
#  'TYTexC',
#  'CI',
#  'CI',
#  'CZ',
#  'CI',
#  'Ca',
#  'cQMm',
#  '2Qkm',
#  '2BMm',
#  'cBMu',
#  '2BMm',
#  'JItBr0eL',
#  'MTtBeRSY',
#  'JIGjr0eL',
#  'JTtje0eY',
#  'MItBeReL',
#  'dm29',
#  'dR29',
#  'dm3C',
#  'jR39',
#  'dm29',
#  'qh5AiVCJ',
#  'zzOrvBiJ',
#  'zh5riBre',
#  'qhOriVie',
#  'qh5rvVie',
#  'dS2LpHRL',
#  'qk2LpHQC',
#  'dkKLyHQC',
#  'kk2LpjQC',
#  'qSKLpHRC',
#  '03Aho3',
#  '092foT',
#  '83Aho3',
#  '89AhY3',
#  '89Afo3',
#  'qmOAzVie',
#  'dmOCzphe',
#  'qm2AzViu',
#  'pzOAzVie',
#  'dm2Cvqhe',
#  'ZvBTHnRr',
#  'wvETe60r',
#  'ZlBTenR2',
#  'wlEPe602',
#  'ZlETHnR2',
#  'Q4z2glq',
#  'V4TThlq',
#  'Q4T1gJq',
#  'Q4T1gJD',
#  'Q8z1gJ6',
#  '7uHLyStp',
#  '7I2ByStC',
#  'dIHLyjQC',
#  'dS2BZjtp',
#  '7SHLySQC',
#  'z5C',
#  'h5C',
#  'z4C',
#  'h58',
#  'h5C',
#  'mvaP',
#  'Y3aE',
#  'Y3OE',
#  'YvOP',
#  'YvaE',
#  '0UQTdZH6',
#  '0UQpDZK6',
#  '0UtTDZK6',
#  '0ftpnYH6',
#  '0fQpDTKM',
#  'hBPHERld',
#  'hNgHSRlv',
#  'WBgHSFld',
#  'WNgLSFtd',
#  'hNPLSFtd',
#  'DoPi2',
#  'DoAi2',
#  'YoAm2',
#  'DpPm2',
#  'DoAi2',
#  '16mbneCD',
#  '16mkUWCD',
#  '16yknWqO',
#  '16mkneqD',
#  'i6ykUeCD',
#  'PTHc9j',
#  '89HkZh',
#  '8jok9h',
#  'PTok9h',
#  'PTHc9h',
#  'qicJpwCl',
#  'qkc7FwCL',
#  'qicJFwCL',
#  '0ic7pwRl',
#  'qic7pwCl']

# %% [markdown]
# # Test

# %%
password = 'importweed'
n_generation = 300
population = 100
best_sample = 20
lucky_few = 20
n_child = 5
chance_of_mutation = 10

pop = generate_population(size=population, min_len=min_len, max_len=max_len)

for g in range(n_generation):
    pop_sorted, pred_len = compute_performace(population=pop, password=password)

    if int(pop_sorted[0][1]) == 100:
        print('SUCCESS! The password is %s' % (pop_sorted[0][0]))
        break
    
    survivors = select_survivors(population_sorted=pop_sorted, best_sample=best_sample, lucky_few=lucky_few, password_len=pred_len)
    
    children = create_children(parents=survivors, n_child=n_child)

    new_generation = mutate_population(population=children, chance_of_mutation=10)
    
    pop = new_generation
    
    print('===== %sth Generation =====' % (g + 1))
    print(pop_sorted[0])
# Out:
# ===== 1th Generation =====
# ['JmqkI8ZPrx', 14.285714285714285]
# ===== 2th Generation =====
# ['WAiprpv5lS', 14.285714285714285]
# ===== 3th Generation =====
# ['W6ipr6vBlS', 14.285714285714285]
# ===== 4th Generation =====
# ['Wxigr6vXLl', 14.285714285714285]
# ===== 5th Generation =====
# ['W65prdv9lJ', 14.285714285714285]
# ===== 6th Generation =====
# ['46lEr6vBLO', 14.285714285714285]
# ===== 7th Generation =====
# ['W6ivrdvBlt', 14.285714285714285]
# ===== 8th Generation =====
# ['Wolgr6vBlJ', 14.285714285714285]
# ===== 9th Generation =====
# ['4xZar6JZLt', 14.285714285714285]
# ===== 10th Generation =====
# ['4xZgrtv9lt', 23.809523809523807]
# ===== 11th Generation =====
# ['WoZgrtJ9lO', 23.809523809523807]
# ===== 12th Generation =====
# ['4x5grtJ9ll', 23.809523809523807]
# ===== 13th Generation =====
# ['W65vrtJBLt', 23.809523809523807]
# ===== 14th Generation =====
# ['4AZgrtJ9LO', 23.809523809523807]
# ===== 15th Generation =====
# ['4x4vrtw9lO', 33.33333333333333]
# ===== 16th Generation =====
# ['4xsvrtw9Lt', 33.33333333333333]
# ===== 17th Generation =====
# ['Wxsvrtw9Ll', 33.33333333333333]
# ===== 18th Generation =====
# ['4xZartw9UO', 33.33333333333333]
# ===== 19th Generation =====
# ['4x5grtwBLt', 33.33333333333333]
# ===== 20th Generation =====
# ['Wxsvrtw9lO', 33.33333333333333]
# ===== 21th Generation =====
# ['Wxsgrtw9ct', 33.33333333333333]
# ===== 22th Generation =====
# ['WxZartw9ct', 33.33333333333333]
# ===== 23th Generation =====
# ['WxsvrtwBrt', 33.33333333333333]
# ===== 24th Generation =====
# ['WxZartw9ct', 33.33333333333333]
# ===== 25th Generation =====
# ['Wxsgrtw9Lt', 33.33333333333333]
# ===== 26th Generation =====
# ['WxZgrtwBlt', 33.33333333333333]
# ===== 27th Generation =====
# ['WxZgrtw9rb', 33.33333333333333]
# ===== 28th Generation =====
# ['WxZgrtwBLt', 33.33333333333333]
# ===== 29th Generation =====
# ['WxZvrtw9ct', 33.33333333333333]
# ===== 30th Generation =====
# ['WxZgrtw9lt', 33.33333333333333]
# ===== 31th Generation =====
# ['Wxgvrtw9ct', 33.33333333333333]
# ===== 32th Generation =====
# ['WxZgrtw9rt', 33.33333333333333]
# ===== 33th Generation =====
# ['WxZvrtw9rt', 33.33333333333333]
# ===== 34th Generation =====
# ['Wx5vrtw9rt', 33.33333333333333]
# ===== 35th Generation =====
# ['WUZvrtw9Ut', 33.33333333333333]
# ===== 36th Generation =====
# ['W7prrtw9Ut', 42.857142857142854]
# ===== 37th Generation =====
# ['WUprrtw9Ut', 42.857142857142854]
# ===== 38th Generation =====
# ['WUprrtw9ct', 42.857142857142854]
# ===== 39th Generation =====
# ['WxpArtw9rt', 42.857142857142854]
# ===== 40th Generation =====
# ['WUpvrtwcct', 42.857142857142854]
# ===== 41th Generation =====
# ['WUpvrtwcct', 42.857142857142854]
# ===== 42th Generation =====
# ['WKpvrtw9ct', 42.857142857142854]
# ===== 43th Generation =====
# ['WUpjrtw9cd', 52.38095238095239]
# ===== 44th Generation =====
# ['WUpjrtw9cd', 52.38095238095239]
# ===== 45th Generation =====
# ['Wxpgrtw9cd', 52.38095238095239]
# ===== 46th Generation =====
# ['Wxpvrtw9rd', 52.38095238095239]
# ===== 47th Generation =====
# ['WUpvrtwcUd', 52.38095238095239]
# ===== 48th Generation =====
# ['WUpurtw2cd', 52.38095238095239]
# ===== 49th Generation =====
# ['WKpgrtw2cd', 52.38095238095239]
# ===== 50th Generation =====
# ['WKpgrtw9cd', 52.38095238095239]
# ===== 51th Generation =====
# ['WUpvrtw9rd', 52.38095238095239]
# ===== 52th Generation =====
# ['WUpurtw9rd', 52.38095238095239]
# ===== 53th Generation =====
# ['Wxpurtw9Ud', 52.38095238095239]
# ===== 54th Generation =====
# ['WKpurtw2cd', 52.38095238095239]
# ===== 55th Generation =====
# ['WKpurtw2cd', 52.38095238095239]
# ===== 56th Generation =====
# ['WKpurtw2cd', 52.38095238095239]
# ===== 57th Generation =====
# ['WKpurtw9rd', 52.38095238095239]
# ===== 58th Generation =====
# ['Wxpurtw9cd', 52.38095238095239]
# ===== 59th Generation =====
# ['Wxpurtw9Ud', 52.38095238095239]
# ===== 60th Generation =====
# ['Wspurtw2od', 52.38095238095239]
# ===== 61th Generation =====
# ['Wspurtw2cd', 52.38095238095239]
# ===== 62th Generation =====
# ['Wspurtw2cd', 52.38095238095239]
# ===== 63th Generation =====
# ['WKp6rtw2cd', 52.38095238095239]
# ===== 64th Generation =====
# ['Wspzrtw2cd', 52.38095238095239]
# ===== 65th Generation =====
# ['Wspurtw2Ud', 52.38095238095239]
# ===== 66th Generation =====
# ['Wxpurtw2od', 52.38095238095239]
# ===== 67th Generation =====
# ['Wspurtw2cd', 52.38095238095239]
# ===== 68th Generation =====
# ['Wspurtw2cd', 52.38095238095239]
# ===== 69th Generation =====
# ['Wxpurtw9cd', 52.38095238095239]
# ===== 70th Generation =====
# ['Wspgrtwecd', 61.904761904761905]
# ===== 71th Generation =====
# ['Wxpgrtwecd', 61.904761904761905]
# ===== 72th Generation =====
# ['Wspurtwecd', 61.904761904761905]
# ===== 73th Generation =====
# ['Wxpurtwecd', 61.904761904761905]
# ===== 74th Generation =====
# ['Wspurtwecd', 61.904761904761905]
# ===== 75th Generation =====
# ['WspurtweUd', 61.904761904761905]
# ===== 76th Generation =====
# ['Wspurtwecd', 61.904761904761905]
# ===== 77th Generation =====
# ['Wxpgrtwecd', 61.904761904761905]
# ===== 78th Generation =====
# ['Wspurtwecd', 61.904761904761905]
# ===== 79th Generation =====
# ['Wspurtwecd', 61.904761904761905]
# ===== 80th Generation =====
# ['Wspurtwecd', 61.904761904761905]
# ===== 81th Generation =====
# ['ispgrtwecd', 71.42857142857143]
# ===== 82th Generation =====
# ['ispgrtwecd', 71.42857142857143]
# ===== 83th Generation =====
# ['ispvrtwecd', 71.42857142857143]
# ===== 84th Generation =====
# ['ispurtwecd', 71.42857142857143]
# ===== 85th Generation =====
# ['iMpurtwecd', 71.42857142857143]
# ===== 86th Generation =====
# ['ispvrtwecd', 71.42857142857143]
# ===== 87th Generation =====
# ['iMpurtwecd', 71.42857142857143]
# ===== 88th Generation =====
# ['iMpurtwecd', 71.42857142857143]
# ===== 89th Generation =====
# ['iMpurtwecd', 71.42857142857143]
# ===== 90th Generation =====
# ['ixpurtwecd', 71.42857142857143]
# ===== 91th Generation =====
# ['iBpurtwecd', 71.42857142857143]
# ===== 92th Generation =====
# ['impurtwecd', 80.95238095238095]
# ===== 93th Generation =====
# ['impurtwecd', 80.95238095238095]
# ===== 94th Generation =====
# ['impurtwecd', 80.95238095238095]
# ===== 95th Generation =====
# ['impurtwecd', 80.95238095238095]
# ===== 96th Generation =====
# ['impurtwecd', 80.95238095238095]
# ===== 97th Generation =====
# ['impurtwecd', 80.95238095238095]
# ===== 98th Generation =====
# ['impurtwecd', 80.95238095238095]
# ===== 99th Generation =====
# ['impurtwecd', 80.95238095238095]
# ===== 100th Generation =====
# ['impurtwecd', 80.95238095238095]
# ===== 101th Generation =====
# ['impurtwecd', 80.95238095238095]
# ===== 102th Generation =====
# ['importweMd', 90.47619047619048]
# ===== 103th Generation =====
# ['importwecd', 90.47619047619048]
# ===== 104th Generation =====
# ['importweMd', 90.47619047619048]
# ===== 105th Generation =====
# ['importwecd', 90.47619047619048]
# ===== 106th Generation =====
# ['importwecd', 90.47619047619048]
# ===== 107th Generation =====
# ['importwecd', 90.47619047619048]
# ===== 108th Generation =====
# ['importwegd', 90.47619047619048]
# ===== 109th Generation =====
# ['importwecd', 90.47619047619048]
# ===== 110th Generation =====
# ['importwecd', 90.47619047619048]
# ===== 111th Generation =====
# ['importwecd', 90.47619047619048]
# ===== 112th Generation =====
# ['importwecd', 90.47619047619048]
# ===== 113th Generation =====
# ['importwecd', 90.47619047619048]
# ===== 114th Generation =====
# ['importwecd', 90.47619047619048]
# ===== 115th Generation =====
# ['importweVd', 90.47619047619048]
# ===== 116th Generation =====
# ['importweVd', 90.47619047619048]
# SUCCESS! The password is importweed
