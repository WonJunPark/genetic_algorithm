# %%
import random
import string

# %% [markdown]
# ## generate population
#
# 첫 세대 생성

# %%
# 비밀번호와 최대 최소 갯수
password = 'abcd1234'
min_len = 2
max_len = 10

# 임의의 문자를 만듬
def generate_word(length):
    result = ''
    x = ''.join(random.sample(string.ascii_letters + string.digits, k=length))
    return x

# 첫번째 세대 생성
def generate_population(size, min_len, max_len):
    population = []
    for i in range(size):
        # generate words with balanced length
        length = i % (max_len - min_len + 1) + min_len
        population.append(generate_word(length))
    return population

# %%
print(generate_word(length=10))
pop = generate_population(size=100, min_len=min_len, max_len=max_len)
pop
# Out:
# YWEjBMdwOZ
# ['Mx',
#  'nbj',
#  '0od5',
#  'CvWsl',
#  'WQplcS',
#  'jqCZz2e',
#  'ebXrt4uP',
#  'hdKJgqRX2',
#  'eZIwFAUS5y',
#  'bH',
#  '9qN',
#  'z4tO',
#  'JSidf',
#  '0DP3JI',
#  'KlHBtyn',
#  'oC7m4EpB',
#  'Z2vH9iUpX',
#  '2xBKy8V3Y7',
#  'no',
#  'tQT',
#  '67VI',
#  'ixpgW',
#  'niaA5L',
#  'BHwiLKG',
#  'BJedXUlv',
#  'J4bvVDLBR',
#  '7CJE1n8Yvq',
#  'Xv',
#  'xKD',
#  'NGr3',
#  '9yTrF',
#  'j3OUA9',
#  'K4FuPVg',
#  '8kfW0DIG',
#  '2Baodg6YC',
#  'ceiM9hA24b',
#  'Kq',
#  'iRd',
#  '6efg',
#  'gzMOC',
#  'NCmtUb',
#  'T8Oh9I7',
#  'PKXgz5Zt',
#  'HGrVjXfd8',
#  'Cl0cwna2mx',
#  'Fi',
#  'LJy',
#  'Ka30',
#  'jiykH',
#  'OEB5GD',
#  'ApsqP13',
#  'KgPkZDv5',
#  'nqHfJ1WR4',
#  '6GuinMZxso',
#  'On',
#  '7jU',
#  'zyQX',
#  'kfKle',
#  'iAcPCL',
#  '6EKYGlL',
#  'JdM7qS42',
#  'GswaZmoOI',
#  'zOqsjStLGd',
#  'A2',
#  'zZq',
#  'nTmv',
#  '49Cyo',
#  'lakcwK',
#  'bwEPGq4',
#  'hFpaMTRt',
#  '0t3vmBd1s',
#  'vOJTIkejm1',
#  'NL',
#  'Yn2',
#  '43g1',
#  'nI1KR',
#  'zsa7j8',
#  'watVN5e',
#  '5l4U9czv',
#  '43huk59QS',
#  '02OGJEDwMe',
#  'lN',
#  'Z4u',
#  'xeBU',
#  'S1L2U',
#  'G8uOQy',
#  'EzOgYSM',
#  'Rowx9vXc',
#  '4FR8cqKxv',
#  'JMEXwdRu37',
#  'DS',
#  'zZB',
#  'Xu4o',
#  'b18Kq',
#  'J9acCP',
#  'Uhc7qkr',
#  'TX502xuf',
#  'v1g9udXGH',
#  'WH08NFf4cb',
#  'tJ']

# %% [markdown]
# ## Fitness Function
#
# 유전자 점수 확인

# %%
def fitness(password, test_word):
    score = 0

    if len(password) != len(test_word):
        return score
    
    # if fit length, I'll give you score 0.5
    len_score = 0.5
    score += len_score

    for i in range(len(password)):
        if password[i] == test_word[i]:
            score += 1

    # 백점 만점에 몇점?
    return score / (len(password) + len_score) * 100

# %%
fitness('abcde', 'abcdE')
# Out:
# 81.81818181818183

# %% [markdown]
# ## Compute Performance and Select Survivors
#
# 정답에 가까운 값 선택

# %%
def compute_performace(population, password):
    performance_list = []
    for individual in population:
        score = fitness(password, individual)

        # we can predict length of password
        if score > 0:
            pred_len = len(individual)
        performance_list.append([individual, score])

    # 점수의 내림차순으로 정렬
    population_sorted = sorted(performance_list, key=lambda x: x[1], reverse=True)
    return population_sorted, pred_len

def select_survivors(population_sorted, best_sample, lucky_few, password_len):
    next_generation = []

    for i in range(best_sample):
        if population_sorted[i][1] > 0:
            next_generation.append(population_sorted[i][0])

    lucky_survivors = random.sample(population_sorted, k=lucky_few)
    for l in lucky_survivors:
        next_generation.append(l[0])
    
    # generate new population if next_generation is too small
    while len(next_generation) < best_sample + lucky_few:
        next_generation.append(generate_word(length=password_len))

    random.shuffle(next_generation)
    return next_generation

pop_sorted, pred_len = compute_performace(pop, password)
survivors = select_survivors(pop_sorted, best_sample=20, lucky_few=20, 
                             password_len=pred_len)

print('Password length must be %s' % pred_len)
survivors
# Out:
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 1.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# 0.5
# 8
# 0.5
# Password length must be 8
# ['I0Texn',
#  'CIOZpf',
#  '2BMu',
#  'MTGjrReY1',
#  'jR39',
#  'zh5riBCJ',
#  'qkKJpHRL',
#  '832fYTvy',
#  'qzOAvVie',
#  'wlBPe6R2',
#  'V4T1glqQ',
#  '7IHBZStpK',
#  'z4ZsR30N',
#  'YvaPCcTW8f',
#  '0UQpnYHM',
#  'WNgLEFtv',
#  'DpPmzb07',
#  'iFybUeCO',
#  '8TocZj',
#  'qkKJpHRL',
#  '0ic7FwCl',
#  'PjHk9hmS',
#  '16mknWqD',
#  'YoAi2',
#  'hBPHSRld',
#  'JftTDZK6nz',
#  'm3OE',
#  'h5C',
#  'dS2LyjQC',
#  'Q8z2hJD',
#  'ZvETHn0r',
#  'dm2Czqhu',
#  '09Aho3',
#  'dS2LyjQC',
#  'qzOAvVie',
#  'dm2Czqhu',
#  'JItBe0SL',
#  'cQkmX7',
#  'qa',
#  'TYodtCIi']

# %% [markdown]
# # Create Children

# %% [markdown]
# 상위 스코어 20개와 무작위로 뽑은 20개를 가지고 교배한다.

# %%
def create_child(individual1, individual2):
    child = ''
    min_len_ind = min(len(individual1), len(individual2))
    for i in range(min_len_ind):
        if (int(100 * random.random()) < 50):
            child += individual1[i]
        else:
            child += individual2[i]
    return child

# 임의로 교배시킨다.
def create_children(parents, n_child):
    next_population = []
    for i in range(int(len(parents)/2)):
        for j in range(n_child):
            next_population.append(create_child(parents[i], parents[len(parents) 
                                                                    - 1 - i]))
    return next_population

children = create_children(survivors, 5)

children
# Out:
# ['T0Tdxn',
#  'T0Texn',
#  'I0oetn',
#  'TYodtC',
#  'TYTexC',
#  'CI',
#  'CI',
#  'CI',
#  'CI',
#  'Ca',
#  'cQMm',
#  '2Qkm',
#  '2BMm',
#  'cBMu',
#  '2BMm',
#  'JItBr0eL',
#  'MTtBeRSY',
#  'JIGjr0eL',
#  'JTtje0eY',
#  'MItBeReL',
#  'dm29',
#  'dR29',
#  'dm3C',
#  'jR39',
#  'dm29',
#  'qh5AiVCJ',
#  'zzOrvBiJ',
#  'zh5riBCe',
#  'qhOriVie',
#  'qh5rvVie',
#  'dS2LpHRL',
#  'qk2LpHQC',
#  'dkKLyHQC',
#  'dk2LpjQC',
#  'qSKLpHRC',
#  '03Aho3',
#  '092foT',
#  '83Aho3',
#  '89AhY3',
#  '89Afo3',
#  'qmOAzVie',
#  'dmOCzqhe',
#  'qm2AzViu',
#  'qzOAzVie',
#  'dm2Cvqhe',
#  'ZvBTHnRr',
#  'wvETe60r',
#  'ZlBTenR2',
#  'wlEPe602',
#  'ZlETHnR2',
#  'Q4z2glq',
#  'V4T2hlq',
#  'Q4T1gJq',
#  'Q4T1gJD',
#  'Q8z1gJD',
#  '7SHLyStp',
#  '7I2ByStC',
#  'dIHLyjQC',
#  'dS2BZjtp',
#  '7SHLySQC',
#  'z5C',
#  'h5C',
#  'z4C',
#  'h5Z',
#  'h5C',
#  'mvaP',
#  'Y3aE',
#  'Y3OE',
#  'YvOP',
#  'YvaE',
#  '0UQTnZH6',
#  '0UQpDZK6',
#  '0UtTDZK6',
#  '0ftpnYH6',
#  '0fQpDZKM',
#  'hBPHERld',
#  'hNgHSRlv',
#  'WBgHSFld',
#  'WNgLSFtd',
#  'hNPLSFtd',
#  'DoPi2',
#  'DoAi2',
#  'YoAm2',
#  'DpPm2',
#  'DoAi2',
#  '16mbneCD',
#  '16mkUWCD',
#  '16yknWqO',
#  '16mkneqD',
#  'i6ykUeCD',
#  'PTHc9j',
#  '8jHkZh',
#  '8jok9h',
#  'PTok9h',
#  'PTHc9h',
#  'qicJpwCl',
#  'qkc7FwCL',
#  'qicJFwCL',
#  '0ic7pwRl',
#  'qic7pwCl']

# %% [markdown]
# # Mutation
#
# 랜덤 인덱스를 뽑아서 값을 랜덤으로 바꿈

# %%
def mutate_word(word):
    idx = int(random.random() * len(word))
    if (idx == 0):
        word = random.choice(string.ascii_letters + string.digits) + word[1:]
    else:
        word = word[:idx] + random.choice(string.ascii_letters + string.digits) + word[idx+1:]
    return word

def mutate_population(population, chance_of_mutation):
    for i in range(len(population)):
        if random.random() * 100 < chance_of_mutation:
            population[i] = mutate_word(population[i])
    return population

new_generation = mutate_population(population=children, chance_of_mutation=10)

new_generation
# Out:
# ['T0Tdxn',
#  'T0Texn',
#  'I0oetn',
#  'TYodtC',
#  'TYTexC',
#  'CI',
#  'CI',
#  'CZ',
#  'CI',
#  'Ca',
#  'cQMm',
#  '2Qkm',
#  '2BMm',
#  'cBMu',
#  '2BMm',
#  'JItBr0eL',
#  'MTtBeRSY',
#  'JIGjr0eL',
#  'JTtje0eY',
#  'MItBeReL',
#  'dm29',
#  'dR29',
#  'dm3C',
#  'jR39',
#  'dm29',
#  'qh5AiVCJ',
#  'zzOrvBiJ',
#  'zh5riBre',
#  'qhOriVie',
#  'qh5rvVie',
#  'dS2LpHRL',
#  'qk2LpHQC',
#  'dkKLyHQC',
#  'kk2LpjQC',
#  'qSKLpHRC',
#  '03Aho3',
#  '092foT',
#  '83Aho3',
#  '89AhY3',
#  '89Afo3',
#  'qmOAzVie',
#  'dmOCzphe',
#  'qm2AzViu',
#  'pzOAzVie',
#  'dm2Cvqhe',
#  'ZvBTHnRr',
#  'wvETe60r',
#  'ZlBTenR2',
#  'wlEPe602',
#  'ZlETHnR2',
#  'Q4z2glq',
#  'V4TThlq',
#  'Q4T1gJq',
#  'Q4T1gJD',
#  'Q8z1gJ6',
#  '7uHLyStp',
#  '7I2ByStC',
#  'dIHLyjQC',
#  'dS2BZjtp',
#  '7SHLySQC',
#  'z5C',
#  'h5C',
#  'z4C',
#  'h58',
#  'h5C',
#  'mvaP',
#  'Y3aE',
#  'Y3OE',
#  'YvOP',
#  'YvaE',
#  '0UQTdZH6',
#  '0UQpDZK6',
#  '0UtTDZK6',
#  '0ftpnYH6',
#  '0fQpDTKM',
#  'hBPHERld',
#  'hNgHSRlv',
#  'WBgHSFld',
#  'WNgLSFtd',
#  'hNPLSFtd',
#  'DoPi2',
#  'DoAi2',
#  'YoAm2',
#  'DpPm2',
#  'DoAi2',
#  '16mbneCD',
#  '16mkUWCD',
#  '16yknWqO',
#  '16mkneqD',
#  'i6ykUeCD',
#  'PTHc9j',
#  '89HkZh',
#  '8jok9h',
#  'PTok9h',
#  'PTHc9h',
#  'qicJpwCl',
#  'qkc7FwCL',
#  'qicJFwCL',
#  '0ic7pwRl',
#  'qic7pwCl']

# %% [markdown]
# # Test

# %%
def password_decoding(pw):
    password = pw
    n_generation = 300
    population = 100
    best_sample = 20
    lucky_few = 20
    n_child = 5
    chance_of_mutation = 10

    pop = generate_population(size=population, min_len=min_len, max_len=max_len)

    for g in range(n_generation):
        pop_sorted, pred_len = compute_performace(population=pop, password=password)

        if int(pop_sorted[0][1]) == 100:
            print('비밀번호 : %s' % (pop_sorted[0][0]))
            break

        survivors = select_survivors(population_sorted=pop_sorted, best_sample=best_sample, lucky_few=lucky_few, password_len=pred_len)

        children = create_children(parents=survivors, n_child=n_child)

        new_generation = mutate_population(population=children, chance_of_mutation=10)

        pop = new_generation

        print('===== %sth Generation =====' % (g + 1))
        print(pop_sorted[0])

# %%
password = 'importweed'
password_decoding(password)
# Out:
# ===== 1th Generation =====
# ['sLxaNtRmZ9', 14.285714285714285]
# ===== 2th Generation =====
# ['b1LPOZw0u3', 14.285714285714285]
# ===== 3th Generation =====
# ['i2cxLXj2ik', 14.285714285714285]
# ===== 4th Generation =====
# ['i1LCOXw0u3', 23.809523809523807]
# ===== 5th Generation =====
# ['i2hniOw07U', 23.809523809523807]
# ===== 6th Generation =====
# ['i1LxvOw0lT', 23.809523809523807]
# ===== 7th Generation =====
# ['i1ctvZw0lT', 23.809523809523807]
# ===== 8th Generation =====
# ['irctvZw0a4', 23.809523809523807]
# ===== 9th Generation =====
# ['i1ctLmw0aT', 23.809523809523807]
# ===== 10th Generation =====
# ['i1ixLFw0l3', 23.809523809523807]
# ===== 11th Generation =====
# ['i1ixvXwLiT', 23.809523809523807]
# ===== 12th Generation =====
# ['imLxvmwX7k', 33.33333333333333]
# ===== 13th Generation =====
# ['imixvXwX7k', 33.33333333333333]
# ===== 14th Generation =====
# ['imLxkXwLiT', 33.33333333333333]
# ===== 15th Generation =====
# ['imitkXwXuT', 33.33333333333333]
# ===== 16th Generation =====
# ['imLokFwX73', 42.857142857142854]
# ===== 17th Generation =====
# ['imLxkXwXuT', 33.33333333333333]
# ===== 18th Generation =====
# ['imctkXwX7k', 33.33333333333333]
# ===== 19th Generation =====
# ['imctkXwLuk', 33.33333333333333]
# ===== 20th Generation =====
# ['imctkXwX7k', 33.33333333333333]
# ===== 21th Generation =====
# ['imcxkXwXiI', 33.33333333333333]
# ===== 22th Generation =====
# ['imLtkXwu73', 33.33333333333333]
# ===== 23th Generation =====
# ['imctkXwu73', 33.33333333333333]
# ===== 24th Generation =====
# ['imxxkXwXik', 33.33333333333333]
# ===== 25th Generation =====
# ['imcxkXwu73', 33.33333333333333]
# ===== 26th Generation =====
# ['imcxkXwu73', 33.33333333333333]
# ===== 27th Generation =====
# ['imcxzXwuik', 33.33333333333333]
# ===== 28th Generation =====
# ['imcxkywui3', 33.33333333333333]
# ===== 29th Generation =====
# ['imctzXwXi3', 33.33333333333333]
# ===== 30th Generation =====
# ['imxckBwu73', 33.33333333333333]
# ===== 31th Generation =====
# ['imcxkXwu73', 33.33333333333333]
# ===== 32th Generation =====
# ['imcxzmwu7k', 33.33333333333333]
# ===== 33th Generation =====
# ['imxckXwu73', 33.33333333333333]
# ===== 34th Generation =====
# ['imcazNwu73', 33.33333333333333]
# ===== 35th Generation =====
# ['imcckXwu7k', 33.33333333333333]
# ===== 36th Generation =====
# ['imxckXwu7k', 33.33333333333333]
# ===== 37th Generation =====
# ['imxtkmwu73', 33.33333333333333]
# ===== 38th Generation =====
# ['imctkmwu73', 33.33333333333333]
# ===== 39th Generation =====
# ['imcckiwu73', 33.33333333333333]
# ===== 40th Generation =====
# ['imcakiwu73', 33.33333333333333]
# ===== 41th Generation =====
# ['imxakmwu73', 33.33333333333333]
# ===== 42th Generation =====
# ['imxxkiwuek', 42.857142857142854]
# ===== 43th Generation =====
# ['imcxkiwuek', 42.857142857142854]
# ===== 44th Generation =====
# ['imcxkiwuek', 42.857142857142854]
# ===== 45th Generation =====
# ['imxckbwuem', 42.857142857142854]
# ===== 46th Generation =====
# ['imxakiwuek', 42.857142857142854]
# ===== 47th Generation =====
# ['imcxrbwue3', 52.38095238095239]
# ===== 48th Generation =====
# ['imxxrmwue3', 52.38095238095239]
# ===== 49th Generation =====
# ['imxarbwue3', 52.38095238095239]
# ===== 50th Generation =====
# ['imxcrmwue3', 52.38095238095239]
# ===== 51th Generation =====
# ['imxcrbwuek', 52.38095238095239]
# ===== 52th Generation =====
# ['imcxrbwzek', 52.38095238095239]
# ===== 53th Generation =====
# ['imxcriwzek', 52.38095238095239]
# ===== 54th Generation =====
# ['imcxrbwuek', 52.38095238095239]
# ===== 55th Generation =====
# ['imccrbwuek', 52.38095238095239]
# ===== 56th Generation =====
# ['imcxrswuek', 52.38095238095239]
# ===== 57th Generation =====
# ['imc5rbwuek', 52.38095238095239]
# ===== 58th Generation =====
# ['imccrbwuek', 52.38095238095239]
# ===== 59th Generation =====
# ['imcxrmwuek', 52.38095238095239]
# ===== 60th Generation =====
# ['imcxrswuek', 52.38095238095239]
# ===== 61th Generation =====
# ['imccrmwuek', 52.38095238095239]
# ===== 62th Generation =====
# ['imcxrswuek', 52.38095238095239]
# ===== 63th Generation =====
# ['imcxrswuek', 52.38095238095239]
# ===== 64th Generation =====
# ['imcxrswuei', 52.38095238095239]
# ===== 65th Generation =====
# ['imccrswRek', 52.38095238095239]
# ===== 66th Generation =====
# ['imcxrswuei', 52.38095238095239]
# ===== 67th Generation =====
# ['imcxrswuek', 52.38095238095239]
# ===== 68th Generation =====
# ['imcxrswuei', 52.38095238095239]
# ===== 69th Generation =====
# ['imcxrswuei', 52.38095238095239]
# ===== 70th Generation =====
# ['imcxrswuei', 52.38095238095239]
# ===== 71th Generation =====
# ['impxrswuek', 61.904761904761905]
# ===== 72th Generation =====
# ['impxrswuek', 61.904761904761905]
# ===== 73th Generation =====
# ['impxrtwuek', 71.42857142857143]
# ===== 74th Generation =====
# ['impxrswuek', 61.904761904761905]
# ===== 75th Generation =====
# ['impxrswued', 71.42857142857143]
# ===== 76th Generation =====
# ['impxrswued', 71.42857142857143]
# ===== 77th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 78th Generation =====
# ['impxrtwued', 80.95238095238095]
# ===== 79th Generation =====
# ['impxrtwued', 80.95238095238095]
# ===== 80th Generation =====
# ['impxrtwued', 80.95238095238095]
# ===== 81th Generation =====
# ['impxrtwmed', 80.95238095238095]
# ===== 82th Generation =====
# ['impxrtwmed', 80.95238095238095]
# ===== 83th Generation =====
# ['impxrtwued', 80.95238095238095]
# ===== 84th Generation =====
# ['impxrtwued', 80.95238095238095]
# ===== 85th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 86th Generation =====
# ['impxrtwFed', 80.95238095238095]
# ===== 87th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 88th Generation =====
# ['impxrtwued', 80.95238095238095]
# ===== 89th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 90th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 91th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 92th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 93th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 94th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 95th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 96th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 97th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 98th Generation =====
# ['impxrtwIed', 80.95238095238095]
# ===== 99th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 100th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 101th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 102th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 103th Generation =====
# ['imp4rtwqed', 80.95238095238095]
# ===== 104th Generation =====
# ['imp4rtwqed', 80.95238095238095]
# ===== 105th Generation =====
# ['imp4rtwqed', 80.95238095238095]
# ===== 106th Generation =====
# ['imp4rtwqed', 80.95238095238095]
# ===== 107th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 108th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 109th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 110th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 111th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 112th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 113th Generation =====
# ['impertwqed', 80.95238095238095]
# ===== 114th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 115th Generation =====
# ['impxrtwqed', 80.95238095238095]
# ===== 116th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 117th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 118th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 119th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 120th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 121th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 122th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 123th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 124th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 125th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 126th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 127th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 128th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 129th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 130th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 131th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 132th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 133th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 134th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 135th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 136th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 137th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 138th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 139th Generation =====
# ['importwTed', 90.47619047619048]
# ===== 140th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 141th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 142th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 143th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 144th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 145th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 146th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 147th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 148th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 149th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 150th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 151th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 152th Generation =====
# ['importwCed', 90.47619047619048]
# ===== 153th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 154th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 155th Generation =====
# ['importwCed', 90.47619047619048]
# ===== 156th Generation =====
# ['importwCed', 90.47619047619048]
# ===== 157th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 158th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 159th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 160th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 161th Generation =====
# ['importwCed', 90.47619047619048]
# ===== 162th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 163th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 164th Generation =====
# ['importwCed', 90.47619047619048]
# ===== 165th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 166th Generation =====
# ['importwqed', 90.47619047619048]
# ===== 167th Generation =====
# ['importwCed', 90.47619047619048]
# ===== 168th Generation =====
# ['importwqed', 90.47619047619048]
# 비밀번호 : importweed
